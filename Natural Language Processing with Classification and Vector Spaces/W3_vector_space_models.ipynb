# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndy-S/machine-learning-fundamental/blob/main/Natural%20Language%20Processing%20with%20Classification%20and%20Vector%20Spaces/W3_vector_space_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vector Space Models

# %% [markdown]
# ## Vector Space Models
# ### Outline
# - Vector space models
# - Advantages
# - Applications

# %% [markdown]
# Natural Language Processing with Classification and Vector Spaces![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Represent words and documents as vectors
# - Representation that captures relative meaning

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Word by Word and Word by Doc.
# ### Outline
# - Co-occurrence --> Vector representation
# - Relationships between words/documents

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - W/W and W/D, *counts* of occurrence
# - Vector Spaces --> Similarity between words/documents

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Linear Algebra in Python with Numpy Code

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Euclidean Distance
# ### Outline
# - Euclidean distance
# - N-dimension vector representations comparison

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Straight line between points
# - Norm of the difference between vectors

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Cosine Similarity: Intuition
# ### Outline
# - Problems with Euclidean Distance
# - Cosine similarity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Cosine similarity when corpora are different sizes

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Cosine Similarity
# ### Outline
# - How to get the cosine of the angle between two vectors
# - Relation of this metric to similarity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Manipulating Words in Vector Spaces
# ### Outline
# - How to use vector representations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Use known relationships to make predictions

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Manipulating Word Embeddings Code

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Visualization and PCA
# ### Outline
# - Some motivation for visualization
# - Principal Component Analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Original Space --> Uncorrelated features --> Dimension reduction
# - Visualization to see words relationships in the vector space

# %%
# SECTION DIVIDER

# %% [markdown]
# ## PCA Algorithm
# ### Outline
# - How to get uncorrelated features
# - How to reduce dimensions while retaining as much information as possible
#
# ### PCA algorithm
# Eigenvector: Uncorrelated features for your data
#
# Eigenvalue: the amount of information retained by each feature

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Summary
# - Eigenvectors give the direction of uncorrelated features
# - Eigenvalues are the variance of the new features
# - Dot product gives the projection on uncorrelated features

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Another Explanation about PCA Code

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Vector Space Models
