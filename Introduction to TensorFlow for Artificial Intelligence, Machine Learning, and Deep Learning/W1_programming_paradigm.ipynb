# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndy-S/machine-learning-fundamental/blob/main/Introduction%20to%20TensorFlow%20for%20Artificial%20Intelligence%2C%20Machine%20Learning%2C%20and%20Deep%20Learning/W1_programming_paradigm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A New Programming Paradigm

# %% [markdown]
# ## A Primer in Machine Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## The 'Hello World' of Neural Networks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 270ms/step - loss: 47.2671
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 37.5711
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 29.9349
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 23.9193
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 19.1790
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 15.4421
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 12.4949
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 10.1691
# Epoch 9/500
# 1/1 [==============================] - 0s 15ms/step - loss: 8.3323
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8804
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.7314
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8209
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# [[18.976791]]

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Housing Prices
