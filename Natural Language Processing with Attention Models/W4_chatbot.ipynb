# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndy-S/machine-learning-fundamental/blob/main/Natural%20Language%20Processing%20with%20Attention%20Models/W4_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chatbot

# %% [markdown]
# ## Tasks with Long Sequences

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Transformer Complexity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Atention Complexity
# - Attention: softmax$(QK^T)V$
# - Q, K, V are all [L,d_model]
# - $QK^T$ is [L,L]
# - Save compute by using area of interest for large L
#
# ### Memory with N Layers
# - Activations need to be stored for backprop
# - Big models are getting bigger
# - Compute vs memory tradeoff

# %%
# SECTION DIVIDER

# %% [markdown]
# ## LSH Attention

# %% [markdown]
# ![Screenshot_20230915_103650.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Nearest Neighbors
# Course:
# - Natural Language Processing with Classification and Vector Spaces
#
# Lessons:
# - KNN
# - Hash Tables and Hash Functions
# - Locality Sensitive Hashing
# - Multiple Planes

# %% [markdown]
# ![Screenshot_20230915_103955.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_104028.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_104132.jpg](data:image/jpeg;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Reformer LSH Code

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Motivation for Reversible Layers: Memory!

# %% [markdown]
# ![Screenshot_20230915_110716.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_110834.jpg](data:image/jpeg;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Reversible Residual Layers

# %% [markdown]
# ![Screenshot_20230915_110834.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111448.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111645.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111603.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111823.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111834.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_111950.jpg](data:image/jpeg;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## RevNet Code

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Reformer

# %% [markdown]
# ![Screenshot_20230915_113820.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_114006.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_113922.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20230915_114041.jpg](data:image/jpeg;base64,...)

# %%
# SECTION DIVIDER

# %% [markdown]
# ## Chatbot
